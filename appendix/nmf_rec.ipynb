# %% [markdown]
# <a href="https://colab.research.google.com/github/banned-books/project_banned_books/blob/main/appendix/nmf_rec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Banned Book Metadata (Goodreads & PEN/American Library Association)

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt

# %%
from numpy.linalg import norm
from nltk.corpus import stopwords
from warnings import simplefilter
from IPython.core.display import HTML
from sklearn.decomposition import NMF
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ### Model and Parameters
# As we have mentioned before, this file is dedicated to creating a nmf recommender system using the goodreads & pen/American library association data. We have decided to create a nmf model with 8 topics.

# %%
# create a list of English stopwords
stop_words = stopwords.words('english')
#Future warning 
simplefilter(action='ignore', category=FutureWarning)
# select number of topic clusters
n_topics = 8
# create an NMF instance
nmf = NMF(n_components=n_topics)

# %% [markdown]
# ## Data Loading

# %%
df = pd.read_csv('banned_books.csv')

# %%
df.head(3)
# Out:
#                                  goodreads_image_url               title  \
# 0  https://images-na.ssl-images-amazon.com/images...       Ace of Spades
# 1  https://images-na.ssl-images-amazon.com/images...  Clap When You Land
# 2  https://images-na.ssl-images-amazon.com/images...          The Poet X
#
#                    author goodreads_published_date  \
# 0  Àbíké-Íyímídé, Faridah               2021-06-01
# 1      Acevedo, Elizabeth               2020-05-05
# 2      Acevedo, Elizabeth               2018-03-06
#
#                                goodreads_description  \
# 0  An incendiary and utterly compelling thriller ...
# 1  In a novel in verse that brims with grief and ...
# 2  Fans of Jacqueline Woodson  Meg Medina  and Ja...
#
#                                       goodreads_tags  \
# 0  dark, lgbtqia+, black, young adult, gay romanc...
# 1  young adult, poetry, contemporary, fiction, au...
# 2  poetry, young adult, contemporary, fiction, au...
#
#                           type_of_ban         state  \
# 0  Banned in Libraries and Classrooms       Florida
# 1                Banned in Classrooms  Pennsylvania
# 2                 Banned in Libraries       Florida
#
#                               district        ban_date origin_of_challenge  \
# 0  Indian River County School District   November 2021       Administrator
# 1         Central York School District  September 2021       Administrator
# 2  Indian River County School District   November 2021       Administrator
#
#                                goodreads_product_url  \
# 0  https://www.goodreads.com/book/show/42603984-a...
# 1  https://www.goodreads.com/book/show/52516332-c...
# 2  https://www.goodreads.com/book/show/33294200-t...
#
#                                           amazon_url secondary_authors  \
# 0  https://www.amazon.com/Ace-Spades-Faridah-Abik...               NaN
# 1  https://www.amazon.com/Clap-When-Land-Elizabet...               NaN
# 2  https://www.amazon.com/Poet-X-Elizabeth-Aceved...               NaN
#
#   illustrators translators
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN

# %% [markdown]
# ### Text Pre-Processing

# %%
text_df = pd.DataFrame(columns = ['title'], data = df.title)
text_df['description'] = df['goodreads_description']+df['goodreads_tags']
text_df = text_df.drop_duplicates()

# %% [markdown]
# ### Vectorization

# %%
# %time v = TfidfVectorizer(stop_words=stop_words, ngram_range=(2, 2), use_idf=True)
# %time V = v.fit_transform(text_df['description'])

df_tf = pd.DataFrame(V.toarray(),
                     columns=v.vocabulary_,
                     index=text_df['title'])
#display(df_tf.head())
# Out:
# CPU times: user 19 µs, sys: 8 µs, total: 27 µs
# Wall time: 27.9 µs
# CPU times: user 323 ms, sys: 14.5 ms, total: 338 ms
# Wall time: 337 ms

# %%
df_tf
# Out:
#                                                     incendiary utterly  \
# title
# Ace of Spades                                                      0.0
# Clap When You Land                                                 0.0
# The Poet X                                                         0.0
# The Poet X                                                         0.0
# Call Me By Your Name                                               0.0
# ...                                                                ...
# The Garden of My Imaan                                             0.0
# Read the World: Rethinking Literacy for Empathy...                 0.0
# American Street                                                    0.0
# Black Enough: Stories of Being Young & Black in...                 0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...                 0.0
#
#                                                     utterly compelling  \
# title
# Ace of Spades                                                      0.0
# Clap When You Land                                                 0.0
# The Poet X                                                         0.0
# The Poet X                                                         0.0
# Call Me By Your Name                                               0.0
# ...                                                                ...
# The Garden of My Imaan                                             0.0
# Read the World: Rethinking Literacy for Empathy...                 0.0
# American Street                                                    0.0
# Black Enough: Stories of Being Young & Black in...                 0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...                 0.0
#
#                                                     compelling thriller  \
# title
# Ace of Spades                                                       0.0
# Clap When You Land                                                  0.0
# The Poet X                                                          0.0
# The Poet X                                                          0.0
# Call Me By Your Name                                                0.0
# ...                                                                 ...
# The Garden of My Imaan                                              0.0
# Read the World: Rethinking Literacy for Empathy...                  0.0
# American Street                                                     0.0
# Black Enough: Stories of Being Young & Black in...                  0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...                  0.0
#
#                                                     thriller shocking  \
# title
# Ace of Spades                                                     0.0
# Clap When You Land                                                0.0
# The Poet X                                                        0.0
# The Poet X                                                        0.0
# Call Me By Your Name                                              0.0
# ...                                                               ...
# The Garden of My Imaan                                            0.0
# Read the World: Rethinking Literacy for Empathy...                0.0
# American Street                                                   0.0
# Black Enough: Stories of Being Young & Black in...                0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...                0.0
#
#                                                     shocking twist  \
# title
# Ace of Spades                                                  0.0
# Clap When You Land                                             0.0
# The Poet X                                                     0.0
# The Poet X                                                     0.0
# Call Me By Your Name                                           0.0
# ...                                                            ...
# The Garden of My Imaan                                         0.0
# Read the World: Rethinking Literacy for Empathy...             0.0
# American Street                                                0.0
# Black Enough: Stories of Being Young & Black in...             0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...             0.0
#
#                                                     twist delves  delves deep  \
# title
# Ace of Spades                                                0.0          0.0
# Clap When You Land                                           0.0          0.0
# The Poet X                                                   0.0          0.0
# The Poet X                                                   0.0          0.0
# Call Me By Your Name                                         0.0          0.0
# ...                                                          ...          ...
# The Garden of My Imaan                                       0.0          0.0
# Read the World: Rethinking Literacy for Empathy...           0.0          0.0
# American Street                                              0.0          0.0
# Black Enough: Stories of Being Young & Black in...           0.0          0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...           0.0          0.0
#
#                                                     deep heart  \
# title
# Ace of Spades                                              0.0
# Clap When You Land                                         0.0
# The Poet X                                                 0.0
# The Poet X                                                 0.0
# Call Me By Your Name                                       0.0
# ...                                                        ...
# The Garden of My Imaan                                     0.0
# Read the World: Rethinking Literacy for Empathy...         0.0
# American Street                                            0.0
# Black Enough: Stories of Being Young & Black in...         0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...         0.0
#
#                                                     heart institutionalized  \
# title
# Ace of Spades                                                           0.0
# Clap When You Land                                                      0.0
# The Poet X                                                              0.0
# The Poet X                                                              0.0
# Call Me By Your Name                                                    0.0
# ...                                                                     ...
# The Garden of My Imaan                                                  0.0
# Read the World: Rethinking Literacy for Empathy...                      0.0
# American Street                                                         0.0
# Black Enough: Stories of Being Young & Black in...                      0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...                      0.0
#
#                                                     institutionalized racism  \
# title
# Ace of Spades                                                            0.0
# Clap When You Land                                                       0.0
# The Poet X                                                               0.0
# The Poet X                                                               0.0
# Call Me By Your Name                                                     0.0
# ...                                                                      ...
# The Garden of My Imaan                                                   0.0
# Read the World: Rethinking Literacy for Empathy...                       0.0
# American Street                                                          0.0
# Black Enough: Stories of Being Young & Black in...                       0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...                       0.0
#
#                                                     ...  ready eat  \
# title                                               ...
# Ace of Spades                                       ...        0.0
# Clap When You Land                                  ...        0.0
# The Poet X                                          ...        0.0
# The Poet X                                          ...        0.0
# Call Me By Your Name                                ...        0.0
# ...                                                 ...        ...
# The Garden of My Imaan                              ...        0.0
# Read the World: Rethinking Literacy for Empathy...  ...        0.0
# American Street                                     ...        0.0
# Black Enough: Stories of Being Young & Black in...  ...        0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...  ...        0.0
#
#                                                     eat birthday  \
# title
# Ace of Spades                                                0.0
# Clap When You Land                                           0.0
# The Poet X                                                   0.0
# The Poet X                                                   0.0
# Call Me By Your Name                                         0.0
# ...                                                          ...
# The Garden of My Imaan                                       0.0
# Read the World: Rethinking Literacy for Empathy...           0.0
# American Street                                              0.0
# Black Enough: Stories of Being Young & Black in...           0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...           0.0
#
#                                                     birthday present  \
# title
# Ace of Spades                                                    0.0
# Clap When You Land                                               0.0
# The Poet X                                                       0.0
# The Poet X                                                       0.0
# Call Me By Your Name                                             0.0
# ...                                                              ...
# The Garden of My Imaan                                           0.0
# Read the World: Rethinking Literacy for Empathy...               0.0
# American Street                                                  0.0
# Black Enough: Stories of Being Young & Black in...               0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...               0.0
#
#                                                     present special  \
# title
# Ace of Spades                                                   0.0
# Clap When You Land                                              0.0
# The Poet X                                                      0.0
# The Poet X                                                      0.0
# Call Me By Your Name                                            0.0
# ...                                                             ...
# The Garden of My Imaan                                          0.0
# Read the World: Rethinking Literacy for Empathy...              0.0
# American Street                                                 0.0
# Black Enough: Stories of Being Young & Black in...              0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...              0.0
#
#                                                     special surprise  \
# title
# Ace of Spades                                                    0.0
# Clap When You Land                                               0.0
# The Poet X                                                       0.0
# The Poet X                                                       0.0
# Call Me By Your Name                                             0.0
# ...                                                              ...
# The Garden of My Imaan                                           0.0
# Read the World: Rethinking Literacy for Empathy...               0.0
# American Street                                                  0.0
# Black Enough: Stories of Being Young & Black in...               0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...               0.0
#
#                                                     surprise waiting  \
# title
# Ace of Spades                                                    0.0
# Clap When You Land                                               0.0
# The Poet X                                                       0.0
# The Poet X                                                       0.0
# Call Me By Your Name                                             0.0
# ...                                                              ...
# The Garden of My Imaan                                           0.0
# Read the World: Rethinking Literacy for Empathy...               0.0
# American Street                                                  0.0
# Black Enough: Stories of Being Young & Black in...               0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...               0.0
#
#                                                     waiting front  \
# title
# Ace of Spades                                                 0.0
# Clap When You Land                                            0.0
# The Poet X                                                    0.0
# The Poet X                                                    0.0
# Call Me By Your Name                                          0.0
# ...                                                           ...
# The Garden of My Imaan                                        0.0
# Read the World: Rethinking Literacy for Empathy...            0.0
# American Street                                               0.0
# Black Enough: Stories of Being Young & Black in...            0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...            0.0
#
#                                                     door picture  food africa  \
# title
# Ace of Spades                                                0.0          0.0
# Clap When You Land                                           0.0          0.0
# The Poet X                                                   0.0          0.0
# The Poet X                                                   0.0          0.0
# Call Me By Your Name                                         0.0          0.0
# ...                                                          ...          ...
# The Garden of My Imaan                                       0.0          0.0
# Read the World: Rethinking Literacy for Empathy...           0.0          0.0
# American Street                                              0.0          0.0
# Black Enough: Stories of Being Young & Black in...           0.0          0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...           0.0          0.0
#
#                                                     cooking realistic
# title
# Ace of Spades                                                     0.0
# Clap When You Land                                                0.0
# The Poet X                                                        0.0
# The Poet X                                                        0.0
# Call Me By Your Name                                              0.0
# ...                                                               ...
# The Garden of My Imaan                                            0.0
# Read the World: Rethinking Literacy for Empathy...                0.0
# American Street                                                   0.0
# Black Enough: Stories of Being Young & Black in...                0.0
# Grandpa Cacao: A Tale of Chocolate, from Farm t...                0.0
#
# [1652 rows x 109103 columns]

# %%
idf_df = pd.DataFrame(
    v.idf_, 
    index=v.vocabulary_,
    columns=['idf_weigths']
    )
    
idf_df.sort_values(by=['idf_weigths']).head(10)

#The greater the IDF, the more relevant it is to an article
#1 mention out of 1 articles = log(1/1) = 0.0
#1 mention out of 2 articles = log(2/1) = 0.69
#1 mention out of 10 articles = log(10/1) = 2.30
#1 mention out of 100 articles = log(100/1) = 4.61
# Out:
#                             idf_weigths
# ramadan wear                   1.712079
# price finally                  1.931837
# frustration graceful           2.558145
# feyre endeavors                2.933884
# expect ben                     2.985397
# rehearsals environmentally     2.994247
# america days                   3.200861
# problem anderson               3.206340
# professional passionate        3.257056
# count every                    3.354101

# %%
# Fit the model to the tf_idf
# %time nmf_features = nmf.fit_transform(V)

# normalize the features
# %time norm_features = normalize(nmf_features)
# Out:
# CPU times: user 1.54 s, sys: 2.91 s, total: 4.45 s
# Wall time: 827 ms
# CPU times: user 535 µs, sys: 1.89 ms, total: 2.42 ms
# Wall time: 498 µs

# %%
# Compare processed VS unprocessed dataframes
print('Original df: ', df_tf.shape)
print('NMF Processed df: ', nmf.components_.shape)
# Out:
# Original df:  (1652, 109103)
# NMF Processed df:  (8, 109103)

# %% [markdown]
# ### Utility Functions

# %%
#Input: df = Grouped Pandas Dataframe , show:default 8 (int) = clusters to show
#Output: dict of "show" n clusters->  {'q'(query): string , 'sim_score'(similarly score): float}
def create_clusters(df, show=8):
    clusters = {}
    for i in range(len(df)):
        clusters[i] = []
        loop = dict(df.loc[i,:].nlargest(show)).items()
        for k,v in loop:
            clusters[i].append({'q':k[0],'sim_score': v})
    return clusters

# %%
#Input: Grouped Pandas Dataframe
#Output: Pandas Dataframe -> index: topics, rows: clusters 
def show_queries(df):
    for col in df.columns:
        df[col] = df[col].apply(lambda x: x['q'])
    return df

# %%
#Input: A= Array, B= Array
#Output: float; computational method 
def cosine_metric(A,B):
    return np.dot(A,B)/(norm(A)*norm(B))

# %%
#Input: Normalized Dataframe
#Output: Dictionary mapping for similarity scores 
def create_recommender(norm_df):
    recomender = {}
    for x in range(len(norm_df)):
        match = norm_df.index[x]
        recomender_scores =[(norm_df.index[y],cosine_metric(norm_df.iloc[x],norm_df.iloc[y])) for y in range(len(norm_df))]
        temp = {match: recomender_scores}
        recomender.update(temp)
    return recomender

# %%
#Input: book_name= string , recomender = dictionary, num_recomendations= number of recomendations 
#Output: tuple (recomender book(s), similarity score)
def get_top_N_recomended(book_name,recomender=dict, num_recomendations=3):
    rec = sorted(recomender.get(book_name), key = lambda x: x[1])[::-1]
    for r in rec:
        if r[0] == book_name:
            rec.remove(r)
    return rec[:num_recomendations]

# %% [markdown]
# ### Clustering Data

# %%
# Create clustered dataframe the NMF clustered df
components = pd.DataFrame(
    nmf.components_, 
    columns=[df_tf.columns]
    ) 
components
# Out:
#   incendiary utterly utterly compelling compelling thriller thriller shocking  \
# 0           0.000091           0.000172            0.000081          0.000091
# 1           0.000000           0.000000            0.000000          0.000000
# 2           0.000107           0.000447            0.001714          0.000107
# 3           0.000010           0.000000            0.000000          0.000010
# 4           0.000066           0.000000            0.000000          0.000066
# 5           0.000000           0.000000            0.000000          0.000000
# 6           0.000011           0.000272            0.000000          0.000011
# 7           0.000000           0.000000            0.000000          0.000000
#
#   shocking twist twist delves delves deep deep heart heart institutionalized  \
# 0       0.000000     0.000092    0.000013   0.000180                0.000028
# 1       0.000000     0.000000    0.000000   0.000000                0.000000
# 2       0.008867     0.000126    0.000104   0.000000                0.000049
# 3       0.000000     0.000014    0.000000   0.000000                0.000000
# 4       0.000000     0.000000    0.000000   0.000000                0.000000
# 5       0.000000     0.000000    0.000005   0.000000                0.000000
# 6       0.000000     0.000004    0.000073   0.002665                0.000000
# 7       0.000000     0.000012    0.000000   0.000010                0.000000
#
#   institutionalized racism  ... ready eat eat birthday birthday present  \
# 0                 0.000091  ...  0.001658     0.001658         0.001658
# 1                 0.000000  ...  0.000000     0.000000         0.000000
# 2                 0.000107  ...  0.000000     0.000000         0.000000
# 3                 0.000010  ...  0.000047     0.000047         0.000047
# 4                 0.000066  ...  0.000000     0.000000         0.000000
# 5                 0.000000  ...  0.000000     0.000000         0.000000
# 6                 0.000011  ...  0.000000     0.000000         0.000000
# 7                 0.000000  ...  0.000296     0.000296         0.000296
#
#   present special special surprise surprise waiting waiting front  \
# 0        0.001658         0.001361         0.000143      0.000287
# 1        0.000000         0.000000         0.000000      0.000000
# 2        0.000000         0.000000         0.003922      0.007843
# 3        0.000047         0.000000         0.000540      0.001079
# 4        0.000000         0.000000         0.000000      0.000000
# 5        0.000000         0.000000         0.000614      0.001228
# 6        0.000000         0.000000         0.000000      0.000000
# 7        0.000296         0.000000         0.000043      0.000087
#
#   door picture food africa cooking realistic
# 0     0.000143    0.001439          0.001361
# 1     0.000000    0.000000          0.000000
# 2     0.003922    0.000046          0.000000
# 3     0.000540    0.000563          0.000000
# 4     0.000000    0.000000          0.000000
# 5     0.000614    0.000000          0.000000
# 6     0.000000    0.000000          0.000000
# 7     0.000043    0.000072          0.000000
#
# [8 rows x 109103 columns]

# %%
# Create clusters
clusters = create_clusters(components) 
clusters
# Out:
# {0: [{'q': 'ramadan wear', 'sim_score': 0.7298361975396181},
#   {'q': 'rehearsals environmentally', 'sim_score': 0.522999063426831},
#   {'q': 'price finally', 'sim_score': 0.3906209950631869},
#   {'q': 'problem anderson', 'sim_score': 0.24310019336440544},
#   {'q': 'professional passionate', 'sim_score': 0.22691454747548961},
#   {'q': 'question colorful', 'sim_score': 0.21368979488844908},
#   {'q': 'grade fiction', 'sim_score': 0.20762070877374222},
#   {'q': 'together love', 'sim_score': 0.20679559999943925}],
#  1: [{'q': 'life city', 'sim_score': 0.6295589197363509},
#   {'q': 'weathers move', 'sim_score': 0.5078407076042809},
#   {'q': 'talk home', 'sim_score': 0.46885796349986353},
#   {'q': 'miss tillie', 'sim_score': 0.32915440725277934},
#   {'q': 'whether growing', 'sim_score': 0.2776032817755634},
#   {'q': 'lit erotic', 'sim_score': 0.22753326657194264},
#   {'q': 'judge asks', 'sim_score': 0.22753326657194264},
#   {'q': 'traces someone', 'sim_score': 0.22753326657194264}],
#  2: [{'q': 'frustration graceful', 'sim_score': 0.5127318720368768},
#   {'q': 'expect ben', 'sim_score': 0.4721079436686839},
#   {'q': 'ceiling defied', 'sim_score': 0.35431520023970114},
#   {'q': 'price finally', 'sim_score': 0.21718416515566882},
#   {'q': 'destroy life', 'sim_score': 0.18412628389922187},
#   {'q': 'hold frustration', 'sim_score': 0.16317987336204595},
#   {'q': 'viewpoints many', 'sim_score': 0.14652149514737303},
#   {'q': 'historical historical', 'sim_score': 0.13820035508542985}],
#  3: [{'q': 'stardust dead', 'sim_score': 0.2664584620500681},
#   {'q': 'author recent', 'sim_score': 0.2664584620500681},
#   {'q': 'carla espana', 'sim_score': 0.2664584620500681},
#   {'q': 'locks open', 'sim_score': 0.2664584620500681},
#   {'q': 'expectancy effects', 'sim_score': 0.2664584620500681},
#   {'q': 'australia high', 'sim_score': 0.26045192255856237},
#   {'q': 'amy diary', 'sim_score': 0.24568853952794364},
#   {'q': 'adam rapp', 'sim_score': 0.1506804987114512}],
#  4: [{'q': 'characters reveal', 'sim_score': 0.29316051683828076},
#   {'q': 'distracts mother', 'sim_score': 0.29316051683828076},
#   {'q': 'daruma doll', 'sim_score': 0.265548595109167},
#   {'q': 'feyre endeavors', 'sim_score': 0.18399172800485525},
#   {'q': 'students never', 'sim_score': 0.14658025841914038},
#   {'q': 'lgbtqia gay', 'sim_score': 0.14658025841914038},
#   {'q': 'gay fiction', 'sim_score': 0.14658025841914038},
#   {'q': 'discovery alek', 'sim_score': 0.14658025841914038}],
#  5: [{'q': 'rich culture', 'sim_score': 0.19844959151869537},
#   {'q': 'wakened muezzin', 'sim_score': 0.13788314606828214},
#   {'q': 'prayer clothes', 'sim_score': 0.13788314606828214},
#   {'q': 'transpire high', 'sim_score': 0.13788314606828214},
#   {'q': 'exams manga', 'sim_score': 0.13788314606828214},
#   {'q': 'manga graphic', 'sim_score': 0.13788314606828214},
#   {'q': 'novels comics', 'sim_score': 0.13788314606828214},
#   {'q': 'romance seinen', 'sim_score': 0.13788314606828214}],
#  6: [{'q': 'negative effects', 'sim_score': 0.5494307370947868},
#   {'q': 'gun shoots', 'sim_score': 0.2604076239414943},
#   {'q': 'age coming', 'sim_score': 0.17832046322395878},
#   {'q': 'perhaps memorable', 'sim_score': 0.17564775598813098},
#   {'q': 'life denver', 'sim_score': 0.17523170167951657},
#   {'q': 'school participation', 'sim_score': 0.17062174594782772},
#   {'q': 'legacy story', 'sim_score': 0.17062174594782772},
#   {'q': 'spell social', 'sim_score': 0.15831203806924993}],
#  7: [{'q': 'outcomes black', 'sim_score': 0.5685876054708661},
#   {'q': 'favors cringe', 'sim_score': 0.44588316762293445},
#   {'q': 'conditioning combined', 'sim_score': 0.37536764587915744},
#   {'q': 'seen bongo', 'sim_score': 0.272837742590435},
#   {'q': 'senior year', 'sim_score': 0.2536409920319324},
#   {'q': 'title characters', 'sim_score': 0.2536409920319324},
#   {'q': 'wrong first', 'sim_score': 0.20880819717843455},
#   {'q': 'worth lying', 'sim_score': 0.1975305428341281}]}

# %%
# Create dataframe using the clustered dict
grouping = pd.DataFrame(clusters).T
grouping['topic'] = grouping[0].apply(lambda x: x['q'])
grouping.drop(0, axis=1, inplace=True)
grouping.set_index('topic', inplace=True)
grouping.head()
# Out:
#                                                                       1  \
# topic
# ramadan wear          {'q': 'rehearsals environmentally', 'sim_score...
# life city             {'q': 'weathers move', 'sim_score': 0.50784070...
# frustration graceful  {'q': 'expect ben', 'sim_score': 0.47210794366...
# stardust dead         {'q': 'author recent', 'sim_score': 0.26645846...
# characters reveal     {'q': 'distracts mother', 'sim_score': 0.29316...
#
#                                                                       2  \
# topic
# ramadan wear          {'q': 'price finally', 'sim_score': 0.39062099...
# life city             {'q': 'talk home', 'sim_score': 0.468857963499...
# frustration graceful  {'q': 'ceiling defied', 'sim_score': 0.3543152...
# stardust dead         {'q': 'carla espana', 'sim_score': 0.266458462...
# characters reveal     {'q': 'daruma doll', 'sim_score': 0.2655485951...
#
#                                                                       3  \
# topic
# ramadan wear          {'q': 'problem anderson', 'sim_score': 0.24310...
# life city             {'q': 'miss tillie', 'sim_score': 0.3291544072...
# frustration graceful  {'q': 'price finally', 'sim_score': 0.21718416...
# stardust dead         {'q': 'locks open', 'sim_score': 0.26645846205...
# characters reveal     {'q': 'feyre endeavors', 'sim_score': 0.183991...
#
#                                                                       4  \
# topic
# ramadan wear          {'q': 'professional passionate', 'sim_score': ...
# life city             {'q': 'whether growing', 'sim_score': 0.277603...
# frustration graceful  {'q': 'destroy life', 'sim_score': 0.184126283...
# stardust dead         {'q': 'expectancy effects', 'sim_score': 0.266...
# characters reveal     {'q': 'students never', 'sim_score': 0.1465802...
#
#                                                                       5  \
# topic
# ramadan wear          {'q': 'question colorful', 'sim_score': 0.2136...
# life city             {'q': 'lit erotic', 'sim_score': 0.22753326657...
# frustration graceful  {'q': 'hold frustration', 'sim_score': 0.16317...
# stardust dead         {'q': 'australia high', 'sim_score': 0.2604519...
# characters reveal     {'q': 'lgbtqia gay', 'sim_score': 0.1465802584...
#
#                                                                       6  \
# topic
# ramadan wear          {'q': 'grade fiction', 'sim_score': 0.20762070...
# life city             {'q': 'judge asks', 'sim_score': 0.22753326657...
# frustration graceful  {'q': 'viewpoints many', 'sim_score': 0.146521...
# stardust dead         {'q': 'amy diary', 'sim_score': 0.245688539527...
# characters reveal     {'q': 'gay fiction', 'sim_score': 0.1465802584...
#
#                                                                       7
# topic
# ramadan wear          {'q': 'together love', 'sim_score': 0.20679559...
# life city             {'q': 'traces someone', 'sim_score': 0.2275332...
# frustration graceful  {'q': 'historical historical', 'sim_score': 0....
# stardust dead         {'q': 'adam rapp', 'sim_score': 0.150680498711...
# characters reveal     {'q': 'discovery alek', 'sim_score': 0.1465802...

# %%
#transform the grouping 
clustered_queries = show_queries(grouping)
clustered_queries.head()
# Out:
#                                                1               2  \
# topic
# ramadan wear          rehearsals environmentally   price finally
# life city                          weathers move       talk home
# frustration graceful                  expect ben  ceiling defied
# stardust dead                      author recent    carla espana
# characters reveal               distracts mother     daruma doll
#
#                                      3                        4  \
# topic
# ramadan wear          problem anderson  professional passionate
# life city                  miss tillie          whether growing
# frustration graceful     price finally             destroy life
# stardust dead               locks open       expectancy effects
# characters reveal      feyre endeavors           students never
#
#                                       5                6  \
# topic
# ramadan wear          question colorful    grade fiction
# life city                    lit erotic       judge asks
# frustration graceful   hold frustration  viewpoints many
# stardust dead            australia high        amy diary
# characters reveal           lgbtqia gay      gay fiction
#
#                                           7
# topic
# ramadan wear                  together love
# life city                    traces someone
# frustration graceful  historical historical
# stardust dead                     adam rapp
# characters reveal            discovery alek

# %%
#remove duplicates 
pages = text_df.title
norm_df = pd.DataFrame(norm_features, index=pages)
norm_df = norm_df[~norm_df.index.duplicated(keep='first')]
norm_df.head()
# Out:
#                                                            0        1  \
# title
# Ace of Spades                                       0.980140  0.00000
# Clap When You Land                                  0.926485  0.00000
# The Poet X                                          0.997919  0.00000
# Call Me By Your Name                                0.980933  0.01476
# How I Paid for College: A Novel of Sex, Theft, ...  0.987106  0.00000
#
#                                                            2         3  \
# title
# Ace of Spades                                       0.000000  0.000000
# Clap When You Land                                  0.137706  0.347262
# The Poet X                                          0.000000  0.064478
# Call Me By Your Name                                0.192846  0.000000
# How I Paid for College: A Novel of Sex, Theft, ...  0.010796  0.000000
#
#                                                           4         5  \
# title
# Ace of Spades                                       0.00000  0.088844
# Clap When You Land                                  0.04534  0.000000
# The Poet X                                          0.00000  0.000000
# Call Me By Your Name                                0.00000  0.000000
# How I Paid for College: A Novel of Sex, Theft, ...  0.00000  0.000000
#
#                                                            6         7
# title
# Ace of Spades                                       0.177289  0.000000
# Clap When You Land                                  0.000000  0.004027
# The Poet X                                          0.000000  0.000000
# Call Me By Your Name                                0.019040  0.000000
# How I Paid for College: A Novel of Sex, Theft, ...  0.159702  0.000000

# %% [markdown]
# ### Recommender

# %%
recomender = create_recommender(norm_df)

# %%
get_top_N_recomended(book_name ='The Poet X',recomender=recomender)
# Out:
# [("What If It's Us ", 0.9998103993037227),
#  ('The Grief Keeper', 0.9995477184832957),
#  ('Putting Makeup on the Fat Boy', 0.9995270966161882)]

# %%
get_top_N_recomended(book_name ='Call Me By Your Name',recomender=recomender)
# Out:
# [('Gravity', 0.9998317576470865),
#  ('7 Days at the Hot Corner', 0.9997877045840184),
#  ('October Mourning: A Song for Matthew Shepard', 0.9996650455537834)]

# %%
get_top_N_recomended(book_name ='How I Paid for College: A Novel of Sex, Theft, Friendship & Musical Theater',recomender=recomender)
# Out:
# [('Love Drugged', 0.9999974802663153),
#  ('The Art of Being Normal', 0.9999416543533003),
#  ('The Extraordinaries ', 0.9999396138049264)]

# %%
df[df['title'] == "The Lady's Guide to Petticoats and Piracy "]["goodreads_description"].to_string(index=False)
# Out:
# 'A year after an accidentally whirlwind grand to...'

# %%
df["goodreads_description"][0]
# Out:
# 'An incendiary and utterly compelling thriller with a shocking twist that delves deep into the heart of institutionalized racism  from an exceptional new YA voice   Welcome to Niveus Private Academy  where money paves the hallways  and the students are never less than perfect  Until now  Because anonymous texter  Aces  is bringing two students  dark secrets to light   Talented musician Devon buries himself in rehearsals  but he can t escape the spotlight when his private photos go public  Head girl Chiamaka isn t afraid to get what she wants  but soon everyone will know the price she has paid for power   Someone is out to get them both  Someone who holds all the aces  And they re planning much more than a high school game   '
