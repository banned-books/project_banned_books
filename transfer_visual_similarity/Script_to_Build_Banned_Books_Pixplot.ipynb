# %% [markdown]
# <a href="https://colab.research.google.com/github/banned-books/project_banned_books/blob/main/transfer_visual_similarity/Script_to_Build_Banned_Books_Pixplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Note
#
# **We have pre-built the PixPlot WebGL site, assets, and updated/needed code to run a customized PixPlot site.**
#
# 1. You can download that folder [here](https://drive.google.com/drive/folders/1yUazlILivqESUJdyDhh5kz7QILqR-W4-?usp=share_link).
# 2. Run `cd pixplot` in your terminal.
# 3. Run `python -m http.server 5000`.
# 4. Open a Chrome browser (best for WebGL sites) and enter `http://localhost:5000/`.
#
#
# **Contrarily, you may run the code below to see a PixPlot build in action on our banned book cover images (with our required dimensionality reduction (UMAP) and KNN parameters).** This code follows the PixPlot documentation.

# %% [markdown]
# # Download the Required Packages
#
# ## THIS IS A SCRIPT TO RE-BUILD THE PIXPLOT
# ## YOU CAN ALSO USE THIS SCRIPT TO BUILD YOUR OWN PIXPLOT
#
# DUE TO THE OLD NATURE OF PIXPLOT, I AM KEEPING THE PIP INSTALLS FOR EASE OF USE/BUILD

# %% [markdown]
# We can't launch the browser from inside this Google colab notebook, but we can zip and download then run on our own machine, once Google's done the heavy lifting.

# %%
# !pip install -U pixplot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 11.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 52.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 66.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 43.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 9.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.4/454.4 MB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 11.3 MB/s eta 0:00:00
# ...

# %%
# !pip install -U typing-extensions==4.2 scikit-learn==0.24.2 scipy==1.4 numpy==1.22 jedi==0.10
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 70.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.8/186.8 kB 25.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, but you have scikit-learn 0.24.2 which is incompatible.
# ...

# %% [markdown]
# One it's installed, either use the filebrowser at left to upload your own images.

# %% [markdown]
# # Mount GDrive to Upload Banned Book Images
# These images were downloaded by our custom [notebook script here](https://colab.research.google.com/drive/13KlWRcc_3auTduSWlAT8MxO2DXEWd8y0).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Run the PixPlot Build With Our Code and Our Parameters

# %% [markdown]
# Now, run PixPlot! The basic command is `pixplot --images "path/to/images/*.jpg"`. Using the demo materials we downloaded, we can also add metadata using the metadata flag. See the [github repo](https://github.com/YaleDHLab/pix-plot) for all of the parameters that you can control.
#
# With PixPlot `n_components=2` is the default, so I won't need to pass that parameter into the build.

# %%
# !pixplot --images "/content/drive/MyDrive/book_cover_images/*" --metadata "/content/drive/MyDrive/Colab Notebooks/data/cleaned_trained_data/metadata.csv" --n_clusters 2 --n_neighbors 5 --min_dist 0.01 --metric 'correlation' --seed 42
# Out:
# 2023-04-16 01:54:54.447023: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-04-16 01:54:56.572601: HDBSCAN not available; using sklearn KMeans
# 2023-04-16 01:55:07.425329: CUML not available; using umap-learn UMAP
# 2023-04-16 01:55:07.426559: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-16 01:55:07.428416: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-04-16 01:55:07.474499: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: NVIDIA A100-SXM4-40GB computeCapability: 8.0
# ...

# %% [markdown]
# # Download the Output Folder (with the built WebGL assets and site code to view PixPlot in browser)

# %% [markdown]
# Then we zip up the newly created `output` folder and download it.

# %%
# zip and download the results!
# !zip -r output.zip ./output

from google.colab import files
files.download('output.zip')
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: output/data/thumbs/53098065.jpg (deflated 3%)
#   adding: output/data/thumbs/34962303.jpg (deflated 4%)
#   adding: output/data/thumbs/31394021.jpg (deflated 4%)
#   adding: output/data/thumbs/43885853.jpg (deflated 3%)
#   adding: output/data/thumbs/44130829.jpg (deflated 6%)
#   adding: output/data/thumbs/42202041.jpg (deflated 2%)
#   adding: output/data/thumbs/16101023.jpg (deflated 4%)
#   adding: output/data/thumbs/36185592.jpg (deflated 3%)
#   adding: output/data/thumbs/36535913.jpg (deflated 3%)
#   adding: output/data/thumbs/11688345.jpg (deflated 5%)
#   adding: output/data/thumbs/18615267.jpg (deflated 2%)
#   adding: output/data/thumbs/49291521.jpg (deflated 4%)
#   adding: output/data/thumbs/27015414.jpg (deflated 3%)
#   adding: output/data/thumbs/33359266.jpg (deflated 3%)
#   adding: output/data/thumbs/78515.jpg (deflated 3%)
#   adding: output/data/thumbs/2789263.jpg (deflated 3%)
# ...

# %% [markdown]
# On your machine, unzip the `output` folder; open a new terminal or command prompt in that folder. Start a server there with a free server, like:
#
# ```
# $python -m http.server 5000
# ```
# and then in your browser go to: `http://localhost:5000/`
